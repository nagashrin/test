# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
stats = pd.read_csv('c:\\users\\nnagaraj\\Desktop\\datascience.csv')
stats
# Out:
#       Training              a              b              c              d  \
# 0     Training  08/07 - 08/11  08/14 - 08/18  08/21 - 08/25  08/28 - 09/01
# 1  A. Hatchett          10.00          20.00           0.09           0.07
# 2    P. Taylor           0.04           0.04           0.04           0.03
# 3     T. Perry           0.03           0.08           0.06           0.05
# 4   W. Cranton           0.03           0.05           0.03           0.02
#
#                e              f              g              h
# 0  09/04 - 09/08  09/11 - 09/15  09/18 - 09/22  09/25 - 09/29
# 1           0.05           0.07           0.04           0.04
# 2           0.03           0.03           0.02           0.02
# 3           0.05           0.05           0.04           0.06
# 4           0.02           0.05           0.04           0.04

# %%
stats[['Training' , 'a', 'b']] [0:3]
# Out:
#       Training              a              b
# 0     Training  08/07 - 08/11  08/14 - 08/18
# 1  A. Hatchett          10.00          20.00
# 2    P. Taylor           0.04           0.04

# %%
stats = stats.drop(0)

# %%
stats
# Out:
#       Training      a      b     c     d     e     f     g     h
# 1  A. Hatchett  10.00  20.00  0.09  0.07  0.05  0.07  0.04  0.04
# 2    P. Taylor   0.04   0.04  0.04  0.03  0.03  0.03  0.02  0.02
# 3     T. Perry   0.03   0.08  0.06  0.05  0.05  0.05  0.04  0.06
# 4   W. Cranton   0.03   0.05  0.03  0.02  0.02  0.05  0.04  0.04

# %%
stats.head()
# Out:
#       Training      a      b     c     d     e     f     g     h
# 1  A. Hatchett  10.00  20.00  0.09  0.07  0.05  0.07  0.04  0.04
# 2    P. Taylor   0.04   0.04  0.04  0.03  0.03  0.03  0.02  0.02
# 3     T. Perry   0.03   0.08  0.06  0.05  0.05  0.05  0.04  0.06
# 4   W. Cranton   0.03   0.05  0.03  0.02  0.02  0.05  0.04  0.04

# %%
stats.columns
# Out:
# Index(['Training', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object')

# %%
stats.columns = ['Trainier', 'week1', 'week2', 'week3', 'week4', 'week5', 'week6', 'week7', 'week8']

# %%
stats.columns
# Out:
# Index(['Trainier', 'week1', 'week2', 'week3', 'week4', 'week5', 'week6',
#        'week7', 'week8'],
#       dtype='object')

# %%
stats
# Out:
#       Trainier  week1  week2 week3 week4 week5 week6 week7 week8
# 1  A. Hatchett  10.00  20.00  0.09  0.07  0.05  0.07  0.04  0.04
# 2    P. Taylor   0.04   0.04  0.04  0.03  0.03  0.03  0.02  0.02
# 3     T. Perry   0.03   0.08  0.06  0.05  0.05  0.05  0.04  0.06
# 4   W. Cranton   0.03   0.05  0.03  0.02  0.02  0.05  0.04  0.04

# %%
Average = [stats.week1 + stats.week2]

# %%
Average
# Out:
# [1    10.0020.00
#  2      0.040.04
#  3      0.030.08
#  4      0.030.05
#  dtype: object]

# %%
stats['Average'] = stats.week1 + stats.week2

# %%
stats
# Out:
#      Trainier week1 week2 week3 week4 week5 week6 week7 week8   Average
# 2   P. Taylor  0.04  0.04  0.04  0.03  0.03  0.03  0.02  0.02  0.040.04
# 3    T. Perry  0.03  0.08  0.06  0.05  0.05  0.05  0.04  0.06  0.030.08
# 4  W. Cranton  0.03  0.05  0.03  0.02  0.02  0.05  0.04  0.04  0.030.05

# %%
stats
# Out:
#      Trainier week1 week2 week3 week4 week5 week6 week7 week8   Average
# 2   P. Taylor  0.04  0.04  0.04  0.03  0.03  0.03  0.02  0.02  0.040.04
# 3    T. Perry  0.03  0.08  0.06  0.05  0.05  0.05  0.04  0.06  0.030.08
# 4  W. Cranton  0.03  0.05  0.03  0.02  0.02  0.05  0.04  0.04  0.030.05

# %%
stats.columns
# Out:
# Index(['Trainier', 'week1', 'week2', 'week3', 'week4', 'week5', 'week6',
#        'week7', 'week8', 'Average'],
#       dtype='object')

# %%
stats = stats.drop('Average',1)

# %%
stats
# Out:
#      Trainier week1 week2 week3 week4 week5 week6 week7 week8
# 2   P. Taylor  0.04  0.04  0.04  0.03  0.03  0.03  0.02  0.02
# 3    T. Perry  0.03  0.08  0.06  0.05  0.05  0.05  0.04  0.06
# 4  W. Cranton  0.03  0.05  0.03  0.02  0.02  0.05  0.04  0.04

# %%
stats.week8.unique()
# Out:
# array(['0.02', '0.06', '0.04'], dtype=object)

# %%
stats.columns
# Out:
# Index(['Trainier', 'week1', 'week2', 'week3', 'week4', 'week5', 'week6',
#        'week7', 'week8'],
#       dtype='object')

# %%
stats.Trainier
# Out:
# 2     P. Taylor
# 3      T. Perry
# 4    W. Cranton
# Name: Trainier, dtype: object

# %%
stats[stats.Trainier == "P. Taylor"]
# Out:
#     Trainier week1 week2 week3 week4 week5 week6 week7 week8
# 2  P. Taylor  0.04  0.04  0.04  0.03  0.03  0.03  0.02  0.02

# %%
stats.iat[2,3]
# Out:
# '0.03'

# %%
stats.at[2,'week1']
# Out:
# '0.04'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
stats = pd.read_csv('c:\\users\\nnagaraj\\Desktop\\datascience.csv')
stats
# Out:
#       Training              a              b              c              d  \
# 0     Training  08/07 - 08/11  08/14 - 08/18  08/21 - 08/25  08/28 - 09/01
# 1  A. Hatchett          10.00          20.00           0.09           0.07
# 2    P. Taylor           0.04           0.04           0.04           0.03
# 3     T. Perry           0.03           0.08           0.06           0.05
# 4   W. Cranton           0.03           0.05           0.03           0.02
#
#                e              f              g              h
# 0  09/04 - 09/08  09/11 - 09/15  09/18 - 09/22  09/25 - 09/29
# 1           0.05           0.07           0.04           0.04
# 2           0.03           0.03           0.02           0.02
# 3           0.05           0.05           0.04           0.06
# 4           0.02           0.05           0.04           0.04

# %%
Report = pd.read_csv('c:\\users\\nnagaraj\\Desktop\\jrm.csv')
Report
# Out:
#                               County   Last Name  First Name  \
# 0                             BAXTER      Causey     Melissa
# 1                             BAXTER         Fry   Katherine
# 2                             BAXTER   Raczynski     Allison
# 3                             BAXTER       Smith     Felecia
# 4                             BAXTER         Fry   Katherine
# 5         Total for BAXTER County: 5         NaN         NaN
# 6                                NaN         NaN         NaN
# 7                                NaN         NaN         NaN
# 8                             BENTON       Young       Erica
# 9                             BENTON    McMellon     Jessica
# 10                            BENTON    MORRISON    MEREDITH
# 11                            BENTON      ROGERS      RACHEL
# 12                            BENTON      ROGERS      RACHEL
# 13                            BENTON       WHITE      MONIKA
# ...

# %%
Report.columns
# Out:
# Index(['County', 'Last Name', 'First Name', 'SSN', 'Worker ID', 'Job Ret Date',
#        'Employer Name', 'Begin Date', 'End Date', 'Hours', 'Wages'],
#       dtype='object')

# %%
Report.columns = ['County', 'LastName', 'FirstName', 'SSN', 'WorkerID', 'JobRetDate',
       'EmployerName', 'BeginDate', 'EndDate', 'Hours', 'Wages']

# %%
Report.columns
# Out:
# Index(['County', 'LastName', 'FirstName', 'SSN', 'WorkerID', 'JobRetDate',
#        'EmployerName', 'BeginDate', 'EndDate', 'Hours', 'Wages'],
#       dtype='object')

# %%
Clientname = [Report.FirstName + " " + Report.LastName]

# %%
Report.append(Clientname)
# Out:
#                               County    LastName   FirstName  \
# 0                             BAXTER      Causey     Melissa
# 1                             BAXTER         Fry   Katherine
# 2                             BAXTER   Raczynski     Allison
# 3                             BAXTER       Smith     Felecia
# 4                             BAXTER         Fry   Katherine
# 5         Total for BAXTER County: 5         NaN         NaN
# 6                                NaN         NaN         NaN
# 7                                NaN         NaN         NaN
# 8                             BENTON       Young       Erica
# 9                             BENTON    McMellon     Jessica
# 10                            BENTON    MORRISON    MEREDITH
# 11                            BENTON      ROGERS      RACHEL
# 12                            BENTON      ROGERS      RACHEL
# 13                            BENTON       WHITE      MONIKA
# ...

# %%
Report[:: 10]
# Out:
#                           County  LastName   FirstName  \
# 0                         BAXTER    Causey     Melissa
# 10                        BENTON  MORRISON    MEREDITH
# 20                        BENTON  MORRISON    MEREDITH
# 30                        BENTON   Parmain      Amanda
# 40                        BENTON    CARTER    ANGELIAH
# 50   Total for BENTON County: 42       NaN         NaN
# 60                         BOONE    Martin        Kali
# 70                           NaN       NaN         NaN
# 80                        CONWAY   UMPHRES       EMILY
# 90                      CRAWFORD   McTyier   RUSCHELLE
# 100                      JOHNSON   Stewart       Dovie
# 110                          NaN       NaN         NaN
# 120  Total for MADISON County: 2       NaN         NaN
# 130                          NaN       NaN         NaN
# 140                          NaN       NaN         NaN
# 150                        SCOTT      Long  Michealene
# ...

# %%
Report
# Out:
#                               County    LastName   FirstName  \
# 0                             BAXTER      Causey     Melissa
# 1                             BAXTER         Fry   Katherine
# 2                             BAXTER   Raczynski     Allison
# 3                             BAXTER       Smith     Felecia
# 4                             BAXTER         Fry   Katherine
# 5         Total for BAXTER County: 5         NaN         NaN
# 6                                NaN         NaN         NaN
# 7                                NaN         NaN         NaN
# 8                             BENTON       Young       Erica
# 9                             BENTON    McMellon     Jessica
# 10                            BENTON    MORRISON    MEREDITH
# 11                            BENTON      ROGERS      RACHEL
# 12                            BENTON      ROGERS      RACHEL
# 13                            BENTON       WHITE      MONIKA
# ...

# %%
Report[Report.County == 'BAXTER']
# Out:
#    County   LastName  FirstName        SSN  WorkerID JobRetDate  \
# 0  BAXTER     Causey    Melissa  431738612    2929.0  1/31/2017
# 1  BAXTER        Fry  Katherine  500117520    2929.0  8/10/2017
# 2  BAXTER  Raczynski    Allison  623763394    2929.0   5/8/2017
# 3  BAXTER      Smith    Felecia  628220717    6811.0  2/22/2017
# 4  BAXTER        Fry  Katherine  500117520    4022.0  8/10/2017
#
#                      EmployerName  BeginDate  EndDate  Hours    Wages
# 0        Subway (GJ Gas N Go LLC)  12/2/2016      NaN   35.0   $8.00
# 1   Town & Country Discount Foods  7/10/2017      NaN   32.0   $8.50
# 2  Kidspiration Pediatric Therapy   5/2/2017      NaN   20.0   $8.50
# 3                        El Chico  1/12/2017      NaN   35.0   $2.15
# 4                Bath & Body Work   6/1/2017      NaN   25.0  $10.50

# %%
Report = Report.drop('SSN', 1)

# %%
Report
# Out:
#                               County    LastName   FirstName  WorkerID  \
# 0                             BAXTER      Causey     Melissa    2929.0
# 1                             BAXTER         Fry   Katherine    2929.0
# 2                             BAXTER   Raczynski     Allison    2929.0
# 3                             BAXTER       Smith     Felecia    6811.0
# 4                             BAXTER         Fry   Katherine    4022.0
# 5         Total for BAXTER County: 5         NaN         NaN       NaN
# 6                                NaN         NaN         NaN       NaN
# 7                                NaN         NaN         NaN       NaN
# 8                             BENTON       Young       Erica    2838.0
# 9                             BENTON    McMellon     Jessica    6353.0
# 10                            BENTON    MORRISON    MEREDITH    8181.0
# 11                            BENTON      ROGERS      RACHEL    2017.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Report = pd.read_csv('c:\\users\\nnagaraj\\Desktop\\jrm.csv')
Report.head()
# Out:
#    County  Last Name First Name        SSN  Worker ID Job Ret Date  \
# 0  BAXTER     Causey    Melissa  431738612     2929.0    1/31/2017
# 1  BAXTER        Fry  Katherine  500117520     2929.0    8/10/2017
# 2  BAXTER  Raczynski    Allison  623763394     2929.0     5/8/2017
# 3  BAXTER      Smith    Felecia  628220717     6811.0    2/22/2017
# 4  BAXTER        Fry  Katherine  500117520     4022.0    8/10/2017
#
#                     Employer Name Begin Date  End Date  Hours    Wages
# 0        Subway (GJ Gas N Go LLC)  12/2/2016       NaN   35.0   $8.00
# 1   Town & Country Discount Foods  7/10/2017       NaN   32.0   $8.50
# 2  Kidspiration Pediatric Therapy   5/2/2017       NaN   20.0   $8.50
# 3                        El Chico  1/12/2017       NaN   35.0   $2.15
# 4                Bath & Body Work   6/1/2017       NaN   25.0  $10.50

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Report.columns
# Out:
# Index(['County', 'Last Name', 'First Name', 'SSN', 'Worker ID', 'Job Ret Date',
#        'Employer Name', 'Begin Date', 'Hours', 'Wages'],
#       dtype='object')

# %%
Report
# Out:
#                               County   Last Name  First Name  \
# 0                             BAXTER      Causey     Melissa
# 1                             BAXTER         Fry   Katherine
# 2                             BAXTER   Raczynski     Allison
# 3                             BAXTER       Smith     Felecia
# 4                             BAXTER         Fry   Katherine
# 5         Total for BAXTER County: 5         NaN         NaN
# 6                                NaN         NaN         NaN
# 7                                NaN         NaN         NaN
# 8                             BENTON       Young       Erica
# 9                             BENTON    McMellon     Jessica
# 10                            BENTON    MORRISON    MEREDITH
# 11                            BENTON      ROGERS      RACHEL
# 12                            BENTON      ROGERS      RACHEL
# 13                            BENTON       WHITE      MONIKA
# ...

# %%
Report.drop(7)
# Out:
#                               County   Last Name  First Name  \
# 0                             BAXTER      Causey     Melissa
# 1                             BAXTER         Fry   Katherine
# 2                             BAXTER   Raczynski     Allison
# 3                             BAXTER       Smith     Felecia
# 4                             BAXTER         Fry   Katherine
# 5         Total for BAXTER County: 5         NaN         NaN
# 6                                NaN         NaN         NaN
# 8                             BENTON       Young       Erica
# 9                             BENTON    McMellon     Jessica
# 10                            BENTON    MORRISON    MEREDITH
# 11                            BENTON      ROGERS      RACHEL
# 12                            BENTON      ROGERS      RACHEL
# 13                            BENTON       WHITE      MONIKA
# 14                            BENTON     SHEPARD       JAMIE
# ...

# %%
head = Report.head()
head
# Out:
#    County  Last Name First Name        SSN  Worker ID Job Ret Date  \
# 0  BAXTER     Causey    Melissa  431738612     2929.0    1/31/2017
# 1  BAXTER        Fry  Katherine  500117520     2929.0    8/10/2017
# 2  BAXTER  Raczynski    Allison  623763394     2929.0     5/8/2017
# 3  BAXTER      Smith    Felecia  628220717     6811.0    2/22/2017
# 4  BAXTER        Fry  Katherine  500117520     4022.0    8/10/2017
#
#                     Employer Name Begin Date  Hours    Wages
# 0        Subway (GJ Gas N Go LLC)  12/2/2016   35.0   $8.00
# 1   Town & Country Discount Foods  7/10/2017   32.0   $8.50
# 2  Kidspiration Pediatric Therapy   5/2/2017   20.0   $8.50
# 3                        El Chico  1/12/2017   35.0   $2.15
# 4                Bath & Body Work   6/1/2017   25.0  $10.50

# %%
visl = sns.distplot(head["Hours"])

# %%
jrm = pd.read_csv('c:\\users\\nnagaraj\\Desktop\\jrm.csv')
jrm
# Out:
#          County   Last Name  First Name        SSN  Worker ID Job Ret Date  \
# 0        BAXTER      Causey     Melissa  431738612       2929     01/31/17
# 1        BAXTER         Fry   Katherine  500117520       2929     08/10/17
# 2        BAXTER   Raczynski     Allison  623763394       2929     05/08/17
# 3        BAXTER       Smith     Felecia  628220717       6811     02/22/17
# 4        BAXTER         Fry   Katherine  500117520       4022     08/10/17
# 5        BENTON       Young       Erica  515788224       2838     11/23/16
# 6        BENTON    McMellon     Jessica  442967421       6353     10/27/16
# 7        BENTON    MORRISON    MEREDITH  241859209       8181     02/17/17
# 8        BENTON      ROGERS      RACHEL  639505871       2017     09/08/17
# 9        BENTON      ROGERS      RACHEL  639505871       5837     09/08/17
# 10       BENTON       WHITE      MONIKA  133767135       1022     06/23/17
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8,4
import warnings
warnings.filterwarnings('ignore')
distplot = sns.distplot(jrm["Hours"])

# %%
distplot = sns.distplot(jrm["Hours"],)

# %%
import pandas as pd

sports = {'Archery': 'Butan',
         'Golf': 'Scottland',
         'Sumo': 'Japan',
         'Taekwondo': 'South Korea'}
s = pd.Series(sports)
s
# Out:
# Archery            Butan
# Golf           Scottland
# Sumo               Japan
# Taekwondo    South Korea
# dtype: object

# %%
s.iloc[3]
# Out:
# 'South Korea'

# %%
s['Golf']
# Out:
# 'Scottland'

# %%
import pandas as pd

sports = {99: 'Butan',
         100: 'Scotland',
         101: 'Japan',
         102: 'South Korea'}
s = pd.Series(sports)
s
# Out:
# 99           Butan
# 100       Scotland
# 101          Japan
# 102    South Korea
# dtype: object

# %%
s.iloc[0]
# Out:
# 'Butan'

# %%
s.loc[99]
# Out:
# 'Butan'

# %%
s = pd.Series([100.00, 120.00, 101,00, 3.00])

# %%
import numpy as np
total = np.sum(s)
total
Average = np.average(s)
Average
# Out:
# 64.799999999999997

# %%
#this creates a big series of random numbers
import pandas as pd
s = pd.Series(np.random.randint(0,1000,1000))
s.head()
# Out:
# 0     81
# 1    158
# 2    945
# 3    697
# 4     33
# dtype: int32

# %%
len(s)
# Out:
# 1000

# %%
original_sports = pd.Series({'Archery': 'Butan',
         'Golf': 'Scottland',
         'Sumo': 'Japan',
         'Taekwondo': 'South Korea'})
cricket_loving_countries = pd.Series(['Australia',
                                     'barbados',
                                     'Pakistan',
                                     'England'],
                                    index=['Cricket',
                                          'Cricket',
                                          'Cricket',
                                          'Cricket'])
all_countries = original_sports.append(cricket_loving_countries)
all_countries
# Out:
# Archery            Butan
# Golf           Scottland
# Sumo               Japan
# Taekwondo    South Korea
# Cricket        Australia
# Cricket         barbados
# Cricket         Pakistan
# Cricket          England
# dtype: object

# %%
all_countries.loc['Cricket']
# Out:
# Cricket    Australia
# Cricket     barbados
# Cricket     Pakistan
# Cricket      England
# dtype: object

# %%
##DataFrame Data Structure##

import pandas as pd

purchase_1 = pd.Series({'Name': 'Chris',
                       'Item purchased': 'Dog Food',
                       'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                       'Item purchased': 'Kitty Litter',
                       'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'vinod',
                       'Item purchased': 'Bird Seed',
                       'Cost': 5.00})
df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index = ['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#          Cost Item purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  vinod

# %%
df.loc['Store 1']
# Out:
#          Cost Item purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn

# %%
df.loc['Store 2']
# Out:
# Cost                      5
# Item purchased    Bird Seed
# Name                  vinod
# Name: Store 2, dtype: object

# %%
df.loc['Store 1', 'Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Name: Cost, dtype: float64

# %%
df.T
# Out:
#                  Store 1       Store 1    Store 2
# Cost                22.5           2.5          5
# Item purchased  Dog Food  Kitty Litter  Bird Seed
# Name               Chris         Kevyn      vinod

# %%
df.T.loc['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2       5
# Name: Cost, dtype: object

# %%
df['Cost']
# Out:
# Store 1    22.5
# Store 1     2.5
# Store 2     5.0
# Name: Cost, dtype: float64

# %%
df.drop('Store 1')
# Out:
#          Cost Item purchased   Name
# Store 2   5.0      Bird Seed  vinod

# %%
df
# Out:
#          Cost Item purchased   Name
# Store 1  22.5       Dog Food  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0      Bird Seed  vinod

# %%
df['Location'] = None
df
# Out:
#          Cost Item purchased   Name Location
# Store 1  22.5       Dog Food  Chris     None
# Store 1   2.5   Kitty Litter  Kevyn     None
# Store 2   5.0      Bird Seed  vinod     None

# %%
df['Location'] = ['NLR', 'NLR', 'LR']
df
# Out:
#          Cost Item purchased   Name Location
# Store 1  22.5       Dog Food  Chris      NLR
# Store 1   2.5   Kitty Litter  Kevyn      NLR
# Store 2   5.0      Bird Seed  vinod       LR

# %%
## Dataframe Indexing and Loading ##

# %%
costs = df['Cost']
costs
# Out:
# Store 1    26.5
# Store 1     6.5
# Store 2     9.0
# Name: Cost, dtype: float64

# %%
df['Cost'] >10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-12b1b88db8f6> in <module>()
# ----> 1 df['Cost'] >10
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
oy = pd.read_csv('C:\\Users\\nnagaraj\\Desktop\\olympics.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa0 in position 0: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-44-270bbe92d734> in <module>()
# ----> 1 oy = pd.read_csv('C:\\Users\\nnagaraj\\Desktop\\olympics.csv')
#
# ...

# %%
oly = pd.read_csv('C:\\Users\\nnagaraj\\Desktop\\jrm.csv')
oly = oly.drop('End Date', 1)
oly
# Out:
#          County   Last Name  First Name        SSN  Worker ID Job Ret Date  \
# 0        BAXTER      Causey     Melissa  431738612       2929     01/31/17
# 1        BAXTER         Fry   Katherine  500117520       2929     08/10/17
# 2        BAXTER   Raczynski     Allison  623763394       2929     05/08/17
# 3        BAXTER       Smith     Felecia  628220717       6811     02/22/17
# 4        BAXTER         Fry   Katherine  500117520       4022     08/10/17
# 5        BENTON       Young       Erica  515788224       2838     11/23/16
# 6        BENTON    McMellon     Jessica  442967421       6353     10/27/16
# 7        BENTON    MORRISON    MEREDITH  241859209       8181     02/17/17
# 8        BENTON      ROGERS      RACHEL  639505871       2017     09/08/17
# 9        BENTON      ROGERS      RACHEL  639505871       5837     09/08/17
# 10       BENTON       WHITE      MONIKA  133767135       1022     06/23/17
# ...

# %%
### Python Fundamentals

# %%
import numpy as np
import pandas as pd

df = np.arange(8)
df1 = df.reshape(2,4)
df1
P = np.arange(10,18)
P1 = P.reshape(2,4)
P1
# Out:
# array([[10, 11, 12, 13],
#        [14, 15, 16, 17]])

# %%
df = pd.read_csv('C:\\Users\\nnagaraj\\Desktop\\2adults.csv')

# %%
df2 = pd.read_csv('c:\\users\\nnagaraj\\Desktop\\Book3.csv')

# %%
df1 = df[:29] 
df1
# Out:
#      County  Case Number                 Name  Federal Count  State Count  \
# 0    BAXTER      7532134          BAKER BEN S             36           12
# 1    BAXTER      7532134         BAKER BRENDA             36           12
# 2    BENTON      7827394      DYCUS MICHAEL O              2            2
# 3    BENTON      7827394     QUINTANA IVORY C              2            2
# 4    BENTON      7843025          LEACH JACOB              2            2
# 5    BENTON      7843025           LEACH TERA              2            2
# 6     BOONE      7831964        MCGEHEE KEVIN              2            1
# 7     BOONE      7831964       MCGEHEE ANDREA              2            2
# 8     BOONE      7848399        QUINN KRYSTAL              2            2
# 9     BOONE      7848399    BARNETT MICHAEL A              2            2
# 10   CONWAY      7587401        PRICE FLOYD E             14           10
# 11   CONWAY      7587401  HASSANSALEM JAMIE M             24            2
# ...

# %%
df2.columns
# Out:
# Index(['County', 'Case Number', 'Case Head', 'FC', 'SC', 'NumNum', 'WPStat',
#        'San'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['County', 'Case Number', 'Name', 'Federal Count', 'State Count', 'SSN',
#        'WP Stat', 'Sanction'],
#       dtype='object')

# %%
pd.merge(df1,df2, how='left', left_on='County', right_on='County')

#pd.merge(staff_df, student_df, how='left',left_on='Name', right_on='Name')
# Out:
#      County  Case Number_x                 Name  Federal Count  State Count  \
# 0    BAXTER        7532134          BAKER BEN S             36           12
# 1    BAXTER        7532134          BAKER BEN S             36           12
# 2    BAXTER        7532134         BAKER BRENDA             36           12
# 3    BAXTER        7532134         BAKER BRENDA             36           12
# 4    BENTON        7827394      DYCUS MICHAEL O              2            2
# 5    BENTON        7827394      DYCUS MICHAEL O              2            2
# 6    BENTON        7827394      DYCUS MICHAEL O              2            2
# 7    BENTON        7827394      DYCUS MICHAEL O              2            2
# 8    BENTON        7827394     QUINTANA IVORY C              2            2
# 9    BENTON        7827394     QUINTANA IVORY C              2            2
# 10   BENTON        7827394     QUINTANA IVORY C              2            2
# ...

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'Washington'},
                        {'Name': 'Sally', 'Role': 'Course Lission', 'Location': 'Arkansas'},
                        {'Name': 'James', 'Role': 'Grader', 'Location': 'Maryland'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': 'Maryland'},
                          {'Name': 'Mike', 'School': 'Law', 'Location': 'Fratern'},
                          {'Name': 'Sally', 'School': 'Engineering', 'Location': 'Arkansas'}])

# %%
staff_df
# Out:
#      Location   Name            Role
# 0  Washington  Kelly  Director of HR
# 1    Arkansas  Sally  Course Lission
# 2    Maryland  James          Grader

# %%
student_df
# Out:
#    Location   Name       School
# 0  Maryland  James     Business
# 1   Fratern   Mike          Law
# 2  Arkansas  Sally  Engineering

# %%
pd.merge(staff_df, student_df, how='left',left_on='Name', right_on='Name')
# Out:
#    Location_x   Name            Role Location_y       School
# 0  Washington  Kelly  Director of HR        NaN          NaN
# 1    Arkansas  Sally  Course Lission   Arkansas  Engineering
# 2    Maryland  James          Grader   Maryland     Business

# %%
pd.merge(staff_df, student_df, how='right',left_on='Name', right_on='Name')
# Out:
#   Location_x   Name            Role Location_y       School
# 0   Arkansas  Sally  Course Lission   Arkansas  Engineering
# 1   Maryland  James          Grader   Maryland     Business
# 2        NaN   Mike             NaN    Fratern          Law

# %%
pd.merge(staff_df, student_df, how= 'outer',left_on='Name', right_on='Location')
# Out:
#    Location_x Name_x            Role Location_y Name_y       School
# 0  Washington  Kelly  Director of HR        NaN    NaN          NaN
# 1    Arkansas  Sally  Course Lission        NaN    NaN          NaN
# 2    Maryland  James          Grader        NaN    NaN          NaN
# 3         NaN    NaN             NaN   Maryland  James     Business
# 4         NaN    NaN             NaN    Fratern   Mike          Law
# 5         NaN    NaN             NaN   Arkansas  Sally  Engineering

# %%
pd.merge(staff_df, student_df, how= 'left',left_on='Name', right_on='Location')
# Out:
#    Location_x Name_x            Role Location_y Name_y School
# 0  Washington  Kelly  Director of HR        NaN    NaN    NaN
# 1    Arkansas  Sally  Course Lission        NaN    NaN    NaN
# 2    Maryland  James          Grader        NaN    NaN    NaN

# %%
import pandas as pd
df = pd.read_csv('c:\\users\\nnagaraj\\Desktop\\census.csv')
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
df = (df.where(df['SUMLEV'] == 50)).dropna().set_index(['STNAME', 'CTYNAME']).rename(columns ={'ESTIMATESBASE2010': 'Estimates Base 2010'})

# %%
import numpy as np
import pandas as pd

def min_max(row):
    data = row[['POPESTIMATE2010', 'POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})
    
df.apply(min_max, 1)
# Out:
#                                    max       min
# STNAME    CTYNAME
# Alabama   Autauga County       55347.0   54660.0
#           Baldwin County      203709.0  183193.0
#           Barbour County       27341.0   26489.0
#           Bibb County          22861.0   22512.0
#           Blount County        57776.0   57373.0
#           Bullock County       10887.0   10606.0
#           Butler County        20944.0   20154.0
#           Calhoun County      118437.0  115620.0
#           Chambers County      34153.0   33993.0
#           Cherokee County      26084.0   25859.0
#           Chilton County       43943.0   43665.0
#           Choctaw County       13841.0   13170.0
#           Clarke County        25767.0   24675.0
#           Clay County          13880.0   13456.0
#           Cleburne County      15072.0   14921.0
#           Coffee County        51211.0   50177.0
#           Colbert County       54514.0   54354.0
#           Conecuh County       13208.0   12662.0
# ...

# %%
def min_max(row):
    data = row[['POPESTIMATE2010', 'POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']]
    row['min'] = np.min(data)
    row['max'] = np.max(data)
    return row
df.apply(min_max,axis = 1)
# Out:
#                               SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME    CTYNAME
# Alabama   Autauga County        50.0     3.0       6.0    1.0     1.0
#           Baldwin County        50.0     3.0       6.0    1.0     3.0
#           Barbour County        50.0     3.0       6.0    1.0     5.0
#           Bibb County           50.0     3.0       6.0    1.0     7.0
#           Blount County         50.0     3.0       6.0    1.0     9.0
#           Bullock County        50.0     3.0       6.0    1.0    11.0
#           Butler County         50.0     3.0       6.0    1.0    13.0
#           Calhoun County        50.0     3.0       6.0    1.0    15.0
#           Chambers County       50.0     3.0       6.0    1.0    17.0
#           Cherokee County       50.0     3.0       6.0    1.0    19.0
#           Chilton County        50.0     3.0       6.0    1.0    21.0
#           Choctaw County        50.0     3.0       6.0    1.0    23.0
# ...

# %%
df = df.reset_index()
df = df.set_index('STNAME')

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# TODO: remove the frame of the chart
plt.figure(frameon=False)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

plt.bar(pos, popularity, align='center')
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]
# TODO: change the bar colors to be less bright blue
# TODO: make one bar, the python bar, a contrasting color
barlist = plt.bar(pos, popularity, align='center')
barlist[0].set_color('r')

# TODO: soften all labels by turning grey
plt.xticks(pos, languages)
plt.ylabel('% Popularity')
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow')

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar colors to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar colors to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)

# TODO: remove the Y label since bars are directly labeled
plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
# TODO: direct label each bar with Y axis values
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar color to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
# remove the Y label since bars are directly labeled
#plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
# direct label each bar with Y axis values
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure()

languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
pos = np.arange(len(languages))
popularity = [56, 39, 34, 34, 29]

# change the bar color to be less bright blue
bars = plt.bar(pos, popularity, align='center', linewidth=0, color='lightslategrey')
# make one bar, the python bar, a contrasting color
bars[0].set_color('#1F77B4')

# soften all labels by turning grey
plt.xticks(pos, languages, alpha=0.8)
# remove the Y label since bars are directly labeled
#plt.ylabel('% Popularity', alpha=0.8)
plt.title('Top 5 Languages for Math & Data \nby % popularity on Stack Overflow', alpha=0.8)

# remove all the ticks (both axes), and tick labels on the Y axis
plt.tick_params(top='off', bottom='off', left='off', right='off', labelleft='off', labelbottom='on')

# remove the frame of the chart
for spine in plt.gca().spines.values():
    spine.set_visible(False)
    
# direct label each bar with Y axis values
for bar in bars:
    plt.gca().text(bar.get_x() + bar.get_width()/2, bar.get_height() - 5, str(int(bar.get_height())) + '%', 
                 ha='center', color='w', fontsize=11)
plt.show()
